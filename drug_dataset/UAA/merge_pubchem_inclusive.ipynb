# %% [markdown]
# ## Merge the curated PubChem and Inclusive Datasets

# %%
import numpy as np
import pandas as pd

# %%
inclusiveDB = pd.read_csv("uaa_data/inclusive_db.csv", sep=";")
pubchemDB = pd.read_csv("uaa_data/ncaa_pubchem.csv")

# %%
inclusiveDB.columns
# Out:
# Index(['ID', 'ncAA abbreviation(s) used in the publication',
#        'ncAA name, as mentioned in the publication', 'ncAA IUPAC name',
#        'ncAA SMILES notation', 'ncAA chemical formula', 'ncAA Structure',
#        'ncAA link for Pubchem, if available',
#        'Application, if provided in the publication',
#        'Canonical amino acid most similar to the ncAA',
#        'aaRS ID (abbr. organism, abbr. natural substrate, RS, mutations if any)',
#        'aaRS origin organism full name',
#        'Amino acid sequence of (mutated) aaRS',
#        'tRNA ID (abbr. organism, tRNA, natural AA transported, anticodon)',
#        'tRNA organism', 'tRNA sequence', 'Codon suppression',
#        'Tested in (protein)', 'Tested in (protein position)',
#        'Tested in (organism/in vitro)', 'Comment (if applicable)',
#        'Publication', 'DOI', 'Publication year'],
#       dtype='object')

# %%
pubchemDB.columns
# Out:
# Index(['QueryName', 'CID', 'Name', 'MolecularFormula', 'MolecularWeight',
#        'IUPACName', 'CanonicalSMILES', 'InChIKey', 'PubChemURL'],
#       dtype='object')

# %%
## Merge on IUPACName
merged_inclusive_pubchem = inclusiveDB.merge(pubchemDB, left_on = 'ncAA IUPAC name', right_on = 'IUPACName')
merged_inclusive_pubchem
# Out:
#        ID ncAA abbreviation(s) used in the publication  \
# 0       1                                not available
# 1       1                                not available
# 2       3                                       pAzPhe
# 3       4                                       pAzPhe
# 4       5                                       pAzPhe
# ..    ...                                          ...
# 856  2285                                         pBzF
# 857  2295                                          AcK
# 858  2391                                         pAzF
# 859  2413                                         pBpA
# 860  2413                                         pBpA
#
#     ncAA name, as mentioned in the publication  \
# 0                          O-methyl-l-tyrosine
# 1                          O-methyl-l-tyrosine
# 2                      p-azido-l-phenylalanine
# 3                      p-azido-l-phenylalanine
# 4                      p-azido-l-phenylalanine
# ..                                         ...
# 856                     p-benzoylphenylalanine
# 857                          N-ε-acetyl-lysine
# 858                    p-azido-L-phenylalanine
# 859                 para-benzoyl-phenylalanine
# 860                 para-benzoyl-phenylalanine
#
#                                     ncAA IUPAC name  \
# 0    (2S)-2-amino-3-(4-methoxyphenyl)propanoic acid
# 1    (2S)-2-amino-3-(4-methoxyphenyl)propanoic acid
# 2      (2S)-2-amino-3-(4-azidophenyl)propanoic acid
# 3      (2S)-2-amino-3-(4-azidophenyl)propanoic acid
# 4      (2S)-2-amino-3-(4-azidophenyl)propanoic acid
# ..                                              ...
# 856  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid
# 857           (2S)-6-acetamido-2-aminohexanoic acid
# 858    (2S)-2-amino-3-(4-azidophenyl)propanoic acid
# 859  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid
# 860  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid
#
#                            ncAA SMILES notation ncAA chemical formula  \
# 0                    COC1=CC=C(C=C1)CC(C(=O)O)N             C10H13NO3
# 1                    COC1=CC=C(C=C1)CC(C(=O)O)N             C10H13NO3
# 2           C1=CC(=CC=C1CC(C(=O)O)N)N=[N+]=[N-]             C9H10N4O2
# 3           C1=CC(=CC=C1CC(C(=O)O)N)N=[N+]=[N-]             C9H10N4O2
# 4           C1=CC(=CC=C1CC(C(=O)O)N)N=[N+]=[N-]             C9H10N4O2
# ..                                          ...                   ...
# 856  C1=CC=C(C=C1)C(=O)C2=CC=C(C=C2)CC(C(=O)O)N             C16H15NO3
# 857                       CC(=O)NCCCCC(C(=O)O)N             C8H16N2O3
# 858         C1=CC(=CC=C1CC(C(=O)O)N)N=[N+]=[N-]             C9H10N4O2
# 859  C1=CC=C(C=C1)C(=O)C2=CC=C(C=C2)CC(C(=O)O)N             C16H15NO3
# 860  C1=CC=C(C=C1)C(=O)C2=CC=C(C=C2)CC(C(=O)O)N             C16H15NO3
#
#      ncAA Structure                ncAA link for Pubchem, if available  \
# 0               NaN  https://pubchem.ncbi.nlm.nih.gov/compound/2723935
# 1               NaN  https://pubchem.ncbi.nlm.nih.gov/compound/2723935
# 2               NaN  https://pubchem.ncbi.nlm.nih.gov/compound/3080772
# 3               NaN  https://pubchem.ncbi.nlm.nih.gov/compound/3080772
# 4               NaN  https://pubchem.ncbi.nlm.nih.gov/compound/3080772
# ..              ...                                                ...
# 856             NaN  https://pubchem.ncbi.nlm.nih.gov/compound/7020128
# 857             NaN    https://pubchem.ncbi.nlm.nih.gov/compound/92832
# 858             NaN  https://pubchem.ncbi.nlm.nih.gov/compound/3080772
# 859             NaN  https://pubchem.ncbi.nlm.nih.gov/compound/7020128
# 860             NaN  https://pubchem.ncbi.nlm.nih.gov/compound/7020128
#
#     Application, if provided in the publication  \
# 0                                 not specified
# 1                                 not specified
# 2                                  crosslinking
# 3                                  crosslinking
# 4                                  crosslinking
# ..                                          ...
# 856                                   labelling
# 857       post translational modification mimic
# 858                          photo-crosslinking
# 859                               not specified
# 860                               not specified
#
#     Canonical amino acid most similar to the ncAA  ... Publication year  \
# 0                                        Tyrosine  ...             2001
# 1                                        Tyrosine  ...             2001
# 2                                   Phenylalanine  ...             2002
# 3                                   Phenylalanine  ...             2002
# 4                                   Phenylalanine  ...             2002
# ..                                            ...  ...              ...
# 856                                 Phenylalanine  ...             2023
# 857                                        Lysine  ...             2023
# 858                                 Phenylalanine  ...             2023
# 859                                 Phenylalanine  ...             2023
# 860                                 Phenylalanine  ...             2023
#
#                      QueryName      CID  \
# 0          O-Methyl-L-tyrosine  2723935
# 1          O-methyl-L-tyrosine  2723935
# 2      p-Azido-L-phenylalanine  3080772
# 3      p-Azido-L-phenylalanine  3080772
# 4      p-Azido-L-phenylalanine  3080772
# ..                         ...      ...
# 856  4-Benzoyl-L-phenylalanine  7020128
# 857  N-epsilon-acetyl-L-lysine    92832
# 858    p-Azido-L-phenylalanine  3080772
# 859  p-Benzoyl-L-phenylalanine  7020128
# 860  4-Benzoyl-L-phenylalanine  7020128
#
#                                                Name MolecularFormula  \
# 0    (2S)-2-amino-3-(4-methoxyphenyl)propanoic acid        C10H13NO3
# 1    (2S)-2-amino-3-(4-methoxyphenyl)propanoic acid        C10H13NO3
# 2      (2S)-2-amino-3-(4-azidophenyl)propanoic acid        C9H10N4O2
# 3      (2S)-2-amino-3-(4-azidophenyl)propanoic acid        C9H10N4O2
# 4      (2S)-2-amino-3-(4-azidophenyl)propanoic acid        C9H10N4O2
# ..                                              ...              ...
# 856  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid        C16H15NO3
# 857           (2S)-6-acetamido-2-aminohexanoic acid        C8H16N2O3
# 858    (2S)-2-amino-3-(4-azidophenyl)propanoic acid        C9H10N4O2
# 859  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid        C16H15NO3
# 860  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid        C16H15NO3
#
#     MolecularWeight                                       IUPACName  \
# 0            195.21  (2S)-2-amino-3-(4-methoxyphenyl)propanoic acid
# 1            195.21  (2S)-2-amino-3-(4-methoxyphenyl)propanoic acid
# 2            206.20    (2S)-2-amino-3-(4-azidophenyl)propanoic acid
# 3            206.20    (2S)-2-amino-3-(4-azidophenyl)propanoic acid
# 4            206.20    (2S)-2-amino-3-(4-azidophenyl)propanoic acid
# ..              ...                                             ...
# 856          269.29  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid
# 857          188.22           (2S)-6-acetamido-2-aminohexanoic acid
# 858          206.20    (2S)-2-amino-3-(4-azidophenyl)propanoic acid
# 859          269.29  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid
# 860          269.29  (2S)-2-amino-3-(4-benzoylphenyl)propanoic acid
#
#     CanonicalSMILES                     InChIKey  \
# 0               NaN  GEYBMYRBIABFTA-VIFPVBQESA-N
# 1               NaN  GEYBMYRBIABFTA-VIFPVBQESA-N
# 2               NaN  NEMHIKRLROONTL-QMMMGPOBSA-N
# 3               NaN  NEMHIKRLROONTL-QMMMGPOBSA-N
# 4               NaN  NEMHIKRLROONTL-QMMMGPOBSA-N
# ..              ...                          ...
# 856             NaN  TVIDEEHSOPHZBR-AWEZNQCLSA-N
# 857             NaN  DTERQYGMUDWYAZ-ZETCQYMHSA-N
# 858             NaN  NEMHIKRLROONTL-QMMMGPOBSA-N
# 859             NaN  TVIDEEHSOPHZBR-AWEZNQCLSA-N
# 860             NaN  TVIDEEHSOPHZBR-AWEZNQCLSA-N
#
#                                             PubChemURL
# 0    https://pubchem.ncbi.nlm.nih.gov/compound/2723935
# 1    https://pubchem.ncbi.nlm.nih.gov/compound/2723935
# 2    https://pubchem.ncbi.nlm.nih.gov/compound/3080772
# 3    https://pubchem.ncbi.nlm.nih.gov/compound/3080772
# 4    https://pubchem.ncbi.nlm.nih.gov/compound/3080772
# ..                                                 ...
# 856  https://pubchem.ncbi.nlm.nih.gov/compound/7020128
# 857    https://pubchem.ncbi.nlm.nih.gov/compound/92832
# 858  https://pubchem.ncbi.nlm.nih.gov/compound/3080772
# 859  https://pubchem.ncbi.nlm.nih.gov/compound/7020128
# 860  https://pubchem.ncbi.nlm.nih.gov/compound/7020128
#
# [861 rows x 33 columns]

# %%
## How about with SwissSideChain?
import os
import pandas as pd

SSC_SMI_DIR = "/Users/sanjitrao/Downloads/L_SMI"


def fix_scc_smiles(s):
    s = s.replace("[NH3]", "[NH3+]")
    s = s.replace("[Cl](=O)=O", "ClS(=O)=O")  # example fix; adjust as needed
    return s

def load_ssc_smiles(smidir: str):
    rows = []
    for fname in os.listdir(smidir):
        if fname.endswith(".smi"):
            path = os.path.join(smidir, fname)
            with open(path, "r") as f:
                line = f.read().strip()

                if not line:
                    continue

                # typical format: "<smiles> <code>"
                parts = line.split()
                smiles = parts[0]
                code = parts[-1]  # 3-letter / extended code ("YCM", "WFP", etc.)

                rows.append((code, smiles))

    data =  pd.DataFrame(rows, columns=["ssc_code", "ssc_smiles"])
    data['ssc_code'] = data['ssc_code'].str.replace('.pdb', '', regex=False)


    data['ssc_smiles'] = data['ssc_smiles'].apply(fix_scc_smiles)
    return data


SSC = load_ssc_smiles(SSC_SMI_DIR)
SSC.head()
# Out:
#   ssc_code                                ssc_smiles
# 0      ALN     O=[C](=O)[C@H](Cc1cccc2c1cccc2)[NH3+]
# 1      OCY              OCCSC[C@@H]([C](=O)=O)[NH3+]
# 2      0AF  [NH3+][C@H]([C](=O)=O)Cc1c[nH]c2c1cccc2O
# 3      26P   OC(=O)[C@H](CCC[C](=[C](=O)=O)=O)[NH3+]
# 4      BHD  O=[C](=O)[C@H]([C@@H]([C](=O)=O)[NH3+])O

# %%
merged_inclusive_pubchem_ssc = merged_inclusive_pubchem.merge(SSC, left_on = 'ncAA SMILES notation', right_on = 'ssc_smiles')
merged_inclusive_pubchem_ssc
# Out:
# Empty DataFrame
# Columns: [ID, ncAA abbreviation(s) used in the publication, ncAA name, as mentioned in the publication, ncAA IUPAC name, ncAA SMILES notation, ncAA chemical formula, ncAA Structure, ncAA link for Pubchem, if available, Application, if provided in the publication, Canonical amino acid most similar to the ncAA, aaRS ID (abbr. organism, abbr. natural substrate, RS, mutations if any), aaRS origin organism full name, Amino acid sequence of (mutated) aaRS, tRNA ID (abbr. organism, tRNA, natural AA transported, anticodon), tRNA organism, tRNA sequence, Codon suppression, Tested in (protein), Tested in (protein position), Tested in (organism/in vitro), Comment (if applicable), Publication, DOI, Publication year, QueryName, CID, Name, MolecularFormula, MolecularWeight, IUPACName, CanonicalSMILES, InChIKey, PubChemURL, ssc_code, ssc_smiles]
# Index: []
#
# [0 rows x 35 columns]
